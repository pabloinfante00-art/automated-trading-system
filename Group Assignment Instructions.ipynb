# %% [markdown]
# # Group Assignment: Development of an Automated Daily Trading System
#
# ## Table of Contents
#
# 1. [Overview](#overview)
#    - [System Architecture](#system-architecture)
# 2. [Data](#data)
#    - [Setting up SimFin platform](#setting-up-simfin-platform)
#    - [Working with the SimFin API](#working-with-the-simfin-api)
# 3. [Project Requirements Definition](#project-requirements-definition)
#    - [Part 1: Data Analytics Module](#part-1-data-analytics-module)
#      - [1.1 Build an ETL to process input data](#11-build-an-etl-to-process-input-data)
#      - [1.2 Build a Machine Learning Model](#12-build-a-machine-learning-model-to-predict-the-next-market-movement)
#      - [1.3 (Optional) Build a Trading Strategy](#13-optional-build-a-trading-strategy-based-on-market-movements)
#    - [Part 2: Web-Based Trading System](#part-2-web-based-trading-system)
#      - [2.1 Python API Wrapper for SimFin](#21-python-api-wrapper-for-simfin)
#      - [2.2 Web Application Development](#22-web-application-development)
#      - [2.3 Cloud-Based Deployment](#23-cloud-based-deployment)
# 4. [AI Usage Policy](#ai-usage-policy)
# 5. [Deliverables](#deliverables)
# 6. [Evaluation](#evaluation)
# 7. [Recommendations](#recommendations)
#    - [Group Organization](#group-organization)
#    - [Development Environment](#development-environment)
#    - [Python Environment](#python-environment)
#    - [Git and GitHub](#git-and-github)
#
# ---
#
# ## Overview
#
# This group assignment requires students to design and implement an **automated daily trading system** using Python. The system will comprise two primary components:
#
# 1. **Data Analytics Module**: This entails constructing a machine learning (ML) model for market movement forecasting. This module must work with at least five US companies.
# 2. **Web-Based Application**: A multi-page interactive web application, developed with **Streamlit**, which enables users to interact with the trading system, visualize predictive analytics, and comprehend the underlying methodologies.
#
# ### System Architecture
#
# The following diagram shows how all the components of the system connect together:
#
# ```mermaid
# %%{init: {'theme': 'base', 'themeVariables': {'primaryColor': '#4f46e5', 'primaryTextColor': '#fff', 'primaryBorderColor': '#3730a3', 'secondaryColor': '#f0abfc', 'tertiaryColor': '#e0e7ff', 'lineColor': '#6366f1', 'fontSize': '13px'}}}%%
# flowchart TB
#     subgraph SRC["SimFin"]
#         direction TB
#         BULK("Bulk Download")
#         API{{"Real-Time API"}}
#     end
#
#     subgraph P1["Part 1: Data Analytics"]
#         direction TB
#         ETL["1.1 ETL"] --> ML["1.2 ML Model"] --> MODEL[("Exported Model")]
#         MODEL -.-> STRAT{{"1.3 Strategy - Optional"}}
#     end
#
#     subgraph P2["Part 2: Web System"]
#         direction TB
#         WRAP>"2.1 API Wrapper"] --> GOLIVE["2.2 Go Live Page"]
#         STRAT -.-> GOLIVE
#         MODEL --> GOLIVE
#         GOLIVE --> CLOUD[/"2.3 Deploy"\]
#     end
#
#     BULK --> ETL
#     API --> WRAP
#     CLOUD --> USER(["End User"])
# ```
#
# **How it works:**
#
# 1. **Offline phase (Part 1):** You download historical data from SimFin in bulk, process it through your ETL pipeline, and use the clean data to train an ML model. The trained model is exported as a file (e.g., `.pkl` or `.joblib`).
# 2. **Online phase (Part 2):** The Streamlit web app uses the PySimFin API wrapper to fetch fresh data from SimFin, applies the same ETL transformations, and feeds the data into the exported model to generate predictions. The user sees the results in the browser.
#
# ---
#
# ## Data
#
# In this project, we will use data extracted from **SimFin** (https://www.simfin.com/). SimFin (short for "Simple Financials") is a platform that provides free and premium access to fundamental financial data for publicly traded companies. It allows users to retrieve historical and real-time financial metrics, making it an essential tool for financial analysis and quantitative trading strategies. SimFin offers structured datasets that include income statements, balance sheets, and cash flow reports, enabling users to develop robust predictive models and trading algorithms.
#
# By integrating SimFin into this project, you will gain hands-on experience working with real-world financial data, utilizing both historical records for model training and real-time API access for the web-based application.
#
# ### Setting up SimFin platform
#
# 1. Register on the SimFin website (https://www.simfin.com/). To do it, just press "Get free account".
# 2. Once you are logged in, you will see an interface with a lot of options. Go to the left panel and you will see these two parts:
#    1. **Bulk download**. This will allow us to download financial history data in one shot. This is necessary for the first part of the project, to train the machine learning model.
#    2. **Data API**. This will allow us to access financial data in real-time, using the SimFin API. This is necessary for the second part of the project, the web app. Once we have our model trained, we will use the API to extract fresh financial information to feed our ML model to provide trading information.
#
# ### Working with the SimFin API
#
# 1. Here you can find the documentation: https://simfin.readme.io/reference/getting-started-1
# 2. This API requires authentication, so you must provide the api-key on every request. To provide the key, just include this element in the header dictionary: `Authorization: api-key <here-your-api-key>`.
# 3. SimFin provides a free tier (what we will use), so some limitations apply when using the Data API. Here you can check them: https://simfin.readme.io/reference/rate-limits. Concretely, the limitation is that **we cannot make more than 2 requests per second**. Take this into account when you develop the web app.
#
# ---
#
# ## Project Requirements Definition
#
# ### Part 1: Data Analytics Module
#
# In this section, students will leverage machine learning techniques to develop a predictive model for stock market movements. The goal is to analyze historical stock price data, identify meaningful patterns, and implement an ML model capable of forecasting the next day's market behavior. This involves data preprocessing, model selection, performance evaluation, and the integration of trading strategies.
#
# #### 1.1 Build an ETL to process input data
#
# This section focuses on the **Extract, Transform, Load (ETL)** process, which is crucial for preparing data for analysis and machine learning modeling. Students will be responsible for extracting historical stock market data and transforming it into a clean and structured format. Emphasis will be placed on handling missing data, normalizing values, and ensuring the dataset is optimized for predictive modeling.
#
# <div class="alert alert-info" role="alert">
#
# **Requirements**
#
# - Download and process financial data.
# - Use Pandas or Polars library.
#
# </div>
#
# **Instructions and suggestions**
#
# 1. Download all necessary data from the SimFin **bulk download** section.
#    1. **(Mandatory) Share prices.** This file includes all the daily share prices for 5 years. This dataset is the main dataset because it contains the minimum data you will need to define the target of your ML model. The project can be done only with this dataset.
#    2. **(Mandatory) Companies.** This file includes just the list of companies, with its related information like the ticker name, the company name, the industry sector, the number of employees, etc.
#    3. **(Optional) The rest of the files.** The rest of the information is not mandatory but can be useful to enrich your set of features for your ML model. There is information about the income statements, balance, etc. These fundamentals can be used as well as the input of your model.
# 2. Build your ETL to process data.
#    1. First, decide what library to use. Polars or Pandas. In this case, we have a considerable amount of data, so develop your coding pipelines with a data sample. Then, when the pipeline is finished, incorporate all data.
#    2. Design and develop all transformation steps in a Jupyter Notebook. Then pass all these transformations into an automated Python script.
#    3. Build your ETL process just for one company and then execute it for all companies you want to include in your application. You can build a unique ETL script with an input parameter specifying the company to use, or build different ETL scripts for each company. Anyway, reuse code.
#    4. Start simple, using the minimum set of data (just Share prices) and a minimum set of transformations.
#    5. Make ETL work for 1 company and then move to the next step. Try to build the entire trading app with just one company. Then go back and include the rest.
#
# #### 1.2 Build a Machine Learning Model to Predict the Next Market Movement
#
# This section focuses on developing a machine-learning model that, taking historical market data, makes predictions for the next trading session. The model's output will serve as the foundation for making informed trading decisions, forming an integral part of the automated trading system.
#
# <div class="alert alert-info" role="alert">
#
# **Requirements**
#
# - The model must make predictions daily.
# - The model must make predictions one day ahead.
# - The machine learning model must be built using Python.
#
# </div>
#
# **Instructions and suggestions**
#
# 1. Decide how to build the ML model. There are several options, depending on the complexity you want:
#    1. **Predicting if the price will rise or fall.** This is the simplest scenario. This involves a classification-based model. Given historical data, the model will predict if the price rises or falls the next day.
#    2. **Predicting the next-day price.** This option requires a more sophisticated approach due to the complexity of stock market dynamics. This involves using regression-based models.
#    3. **Others.** You can invent more options to define your ML models, for example: instead of predicting if the price will rise or fall, you can include more categories like high rise, low rise, stay, low fall, and high fall. This approach will involve the construction of a multi-class classification model.
# 2. Remember that the output of the model will be used later to make the trading decision (to buy, to sell, or to hold) if you decide to do it.
# 3. Start developing the code in a Jupyter Notebook, and then build a script to generate your model based on input data (the output of the ETL).
# 4. Start simple, don't complicate too much. The main goal is to make everything work.
#    1. Start building a simple Logistic Regression that gives you if price will rise or fall.
#    2. Export the model to make real-time predictions in the web application.
#    3. Then, when everything is working, come back to improve the model.
#
# #### 1.3 (Optional) Build a Trading Strategy Based on Market Movements
#
# A trading strategy is a set of predefined rules that determine when to buy, sell, or hold assets in response to market conditions. This section focuses on designing a systematic approach to making trading decisions based on the output of the machine learning model. Students are encouraged to backtest their strategy against historical data to evaluate its performance before implementation in a live environment.
#
# **Instructions and suggestions**
#
# 1. Define your trading strategy. For example, imagine we are using the simple binary classification model that predicts if the price will rise or fall:
#    1. **Strategy 1: Buy-and-Hold.**
#       - If the price rises, I buy 1 share.
#       - If the price falls, I hold.
#       - I will sell only when I reach a predefined level of profit.
#    2. **Strategy 2: Buy-and-Sell.**
#       - If the price rises, I buy 1 share now.
#       - If the price falls, I will sell 1 share now.
# 2. Apply the strategy to the output of the model. The output of the strategy must tell us one of these actions:
#    1. If BUY, and how many shares (or how much money)
#    2. If SELL, and how many shares (or how much money)
#    3. If HOLD
# 3. Again, start simple. Define simple rules just to make everything work. Then you can come back and improve your trading strategy.
#
# ---
#
# ### Part 2: Web-Based Trading System
#
# This section focuses on developing a fully functional web-based trading system that integrates the machine learning model and API wrapper into an interactive user interface. The goal is to provide a seamless experience for users to analyze market trends and view the model-generated signals. Additionally, the system must be deployed to a cloud platform to ensure accessibility and scalability.
#
# #### 2.1 Python API Wrapper for SimFin
#
# Students will construct a Python API wrapper to interact with SimFin. The goal is to simplify the interaction with the API just by using Python. This wrapper consists of a set of classes to retrieve share prices or any other useful information.
#
# <div class="alert alert-info" role="alert">
#
# **Requirements**
#
# - Implement an object-oriented code to extract data from SimFin.
# - The library must allow users to retrieve stock price data for specified companies in the specified period.
#
# </div>
#
# **Instructions and suggestions**
#
# 1. Define the structure of the API. Here I provide an example of a simple Python wrapper for the API. Take it as a suggestion and simplify or complicate it as you consider.
# 2. Build a class `PySimFin` with the following capabilities:
#    1. **Constructor.** This will create a new instance for the class to interact with the API. In this constructor, you can initialize the base endpoint and the header with the "api-key".
#    2. **`get_share_prices(ticker: str, start: str, end: str)`**. This method will return a DataFrame with all prices for the provided ticker in the provided time range.
#    3. **`get_financial_statement(ticker: str, start: str, end: str)`**. This method will return a DataFrame with financial statements for the ticker provided in the provided time range.
# 3. Include error handling (exceptions) mechanisms.
#
# #### 2.2 Web Application Development
#
# Students will develop an interactive web application with the following components:
#
# **2.2.1 Home Page**
#
# - Present an overview of the trading system and its core functionalities.
# - Provide information about the development team.
# - Explain the system's purpose and objectives clearly for the end-user.
#
# **2.2.2 Go Live Page**
#
# - Implement a **stock ticker selector** to allow users to choose from available companies.
# - Display **real-time and historical stock market data** using the Python wrapper for SimFin.
# - Apply the ETL transformations and predictive model to data extracted from SimFin.
# - Show **model-generated trading signals** (if the price rises or falls, or suggestions about buying or selling if you have a trading strategy).
#
# **2.2.3 Backtesting Page (Optional, if you built the trading strategy)**
#
# - Provide an interactive backtesting simulator allowing users to evaluate historical trade scenarios based on model predictions.
#
# **Instructions and suggestions**
#
# - The recommendation is that you use **Streamlit**, which is the library we see during the semester.
# - To build a multi-page app in Streamlit you can follow these instructions from Streamlit docs: https://docs.streamlit.io/get-started/tutorials/create-a-multipage-app
# - Additionally, you can include more pages to support your work. For example, you can include a page to illustrate how you did all the ML process: feature selection, data processing, evaluation methods employed.
#
# #### 2.3 Cloud-Based Deployment
#
# <div class="alert alert-info" role="alert">
#
# **Requirements**
#
# - Deploy the Streamlit-based web application on **Streamlit Cloud** or an equivalent cloud hosting service (AWS, GCP, Heroku).
# - Ensure **public accessibility** of the deployed application without requiring local installations.
# - Provide a **public link** to the final deployed system.
#
# </div>
#
# ---
#
# ## AI Usage Policy
#
# Artificial intelligence tools (ChatGPT, GitHub Copilot, Claude, etc.) are **allowed and encouraged** in this project. AI is a professional tool used daily in the software industry, and learning to use it effectively is part of your development as data professionals.
#
# ### Guidelines
#
# - **You may use AI for**: code generation, debugging, brainstorming approaches, learning new concepts, writing documentation, and solving technical problems.
# - **You are responsible for**: understanding every line of code in your project. If you cannot explain it, you should not submit it.
# - **You must submit**: an **AI Usage Log**, a short document (`AI_USAGE_LOG.md`) included in your GitHub repository where you describe:
#   - What AI tools you used.
#   - For what tasks (e.g., "Used ChatGPT to debug the ETL pipeline", "Used Copilot to generate the API wrapper boilerplate").
#   - What worked well and what didn't.
#   - What you learned from the interaction.
#
# ### Why this matters
#
# The AI Usage Log is not about policing. It is about **reflection**. Teams that use AI thoughtfully (understanding what it generates, iterating on it, combining it with their own knowledge) will produce better work than teams that blindly copy-paste. Your understanding of the code will be evaluated during the **in-class presentation and Q&A**.
#
# ---
#
# ## Deliverables
#
# | Deliverable | Description |
# |---|---|
# | **GitHub Repository** | A public GitHub repository containing: well-documented and structured Python source code, a `requirements.txt`, a `README.md`, and the `AI_USAGE_LOG.md`. See details below. |
# | **Live Web Application** | Hosted on a cloud platform and accessible via a public link. |
# | **Executive Summary** | A brief document (PDF, 2-4 pages max) explaining how you approached each part of the project. It should cover: the data sources used, the ETL process, the ML model chosen and why, the web app architecture, challenges faced, and conclusions. This is not a technical report. Write it as if you were explaining the project to a non-technical stakeholder. Include diagrams or screenshots if they help illustrate your points. Submit this document in the GitHub repository under a `/docs` folder. |
# | **In-Class Presentation** | A 10-minute group session including a live demo and individual Q&A (see Evaluation section). |
#
# ### About the GitHub Repository
#
# Your repository is the main deliverable. It should be well-organized and easy to navigate. In addition to your source code, it must include the following files at the root level:
#
# **`README.md`** is the first thing anyone sees when they visit your repository. Think of it as the landing page of your project. It is a Markdown file that should contain:
#
# - The project name and a brief description of what it does.
# - The names of the team members.
# - Instructions on how to install and run the project locally (what commands to execute, what environment variables to set, etc.).
# - A link to the deployed web application.
# - A brief description of the project structure (what is in each folder).
#
# A good README allows someone who has never seen your project to understand what it is and get it running in minutes.
#
# **`requirements.txt`** is a standard Python file that lists all the external libraries your project depends on, along with their versions. This file allows anyone to recreate your exact environment by running `pip install -r requirements.txt`. For example:
#
# ```
# pandas==2.1.4
# streamlit==1.29.0
# scikit-learn==1.3.2
# requests==2.31.0
# ```
#
# To generate this file from your current environment, you can run `pip freeze > requirements.txt`. However, review it afterwards to remove any unnecessary packages that are not actually used in your project.
#
# **`AI_USAGE_LOG.md`** is a document where your team records how AI tools were used throughout the project. It should describe what tools you used, for what tasks, what worked well, what didn't, and what you learned from the interactions. See the [AI Usage Policy](#ai-usage-policy) section for full details.
#
# ---
#
# ## Evaluation
#
# The evaluation is divided into three components:
#
# ### 1. Project (40%, Group Grade)
#
# All members of the group will receive the same grade in this component. The project will be evaluated based on the following criteria:
#
# | Criteria | Weight |
# |---|---|
# | **1.1 ETL**: Data is properly extracted, transformed, and structured | 20% |
# | **2.1 API Wrapper**: Object-oriented design, error handling | 20% |
# | **2.2 Web Application**: Functional, usable, displays data and predictions correctly | 25% |
# | **1.2 ML Model**: Model works, basic methodology applied | 10% |
# | **2.3 Deployment**: Application is live and publicly accessible | 15% |
# | **Deliverables**: README, requirements.txt, code structure, AI Usage Log, Executive Summary | 10% |
#
# **Important**: The quality of ML model predictions or the level of profit made by your trading system is **not** part of the evaluation. Predicting stock market behavior is a hard task and is not the goal of this project. What matters is your Python engineering: clean code, proper methodology, and a working system.
#
# ### 2. In-Class Presentation and Q&A (45%, Individual Grade)
#
# Each group will have **10 minutes** during a dedicated class session:
#
# | Time | Activity |
# |---|---|
# | **0-5 min** | **Live demo** of your deployed application. Show the app working with different tickers. No slides, just the real product. |
# | **5-10 min** | **Individual Q&A**. The professor will ask directed questions to specific group members about any part of the project. |
#
# **How the Q&A works:**
#
# - The professor decides who answers each question. No volunteering.
# - You may be asked about **your part** of the project ("Explain how the ETL pipeline works") or about **another part** ("Why did the team choose this ML approach?").
# - You are expected to understand the **entire system**, not just the part you coded.
#
# **This is where AI usage is validated.** If you used AI tools without understanding what was generated, you will not be able to answer these questions. Conversely, if you used AI effectively and learned from it, you will answer confidently.
#
# ### 3. Peer Evaluation (15%, Individual Grade)
#
# After the project deadline, each student will fill out an anonymous peer evaluation form rating every teammate on:
#
# - **Effort and dedication** (1-5)
# - **Quality of contributions** (1-5)
# - **Communication and collaboration** (1-5)
#
# The average score will be used to compute an individual multiplier on this component. All members of the group **must participate** in the project to receive a grade.
#
# ### Optional Task
#
# The trading strategy (section 1.3) is optional. If implemented, it will increase the final grade by **up to 1 bonus point**. The maximum attainable grade is **11**.
#
# ---
#
# ## Recommendations
#
# ### Group Organization
#
# You must act as a professional multidisciplinary team. Here are some suggestions:
#
# 1. **Sit down together and analyze what to do.** Ensure everyone understands the full scope.
# 2. **Divide the group into 2 teams:**
#    - **ML team.** In charge of Part 1 (ETL, ML model, trading strategy). If someone in the group knows about finance, even better.
#    - **DEV team.** In charge of Part 2 (API wrapper, Streamlit web app, cloud deployment).
# 3. **Work incrementally, in iterations.** Build the first functioning version as soon as possible. To achieve this, start simple:
#    1. In ETL, don't use all data sources at the beginning.
#    2. In the ML part, don't try to implement complicated neural networks at the start. Begin with something simple.
#    3. In the API, start developing just the method to access the data you need.
#    4. In the Streamlit web app, don't worry too much about look and feel. Focus on showing the information correctly.
#    5. Do the optional tasks at the end, if you want to do them.
# 4. **Everyone must understand the whole project.** Even if you only coded the ETL, you should be able to explain how the web app works. This will be tested in the Q&A.
#
# ### Development Environment
#
# Using **VS Code** as your code editor is not mandatory, but it is highly recommended. This project is a great opportunity to get comfortable with a professional development environment that you will encounter in the industry. Here are some reasons to consider it:
#
# - **Integrated terminal.** You can run your Python scripts, Streamlit apps, and git commands without leaving the editor.
# - **Extensions.** Install the Python extension for syntax highlighting, linting, and debugging. The Jupyter extension lets you run notebooks directly in VS Code.
# - **Live collaboration.** The Live Share extension allows multiple team members to edit the same code in real time, which is useful for pair programming or debugging sessions.
# - **Git integration.** VS Code has built-in git support that makes it easy to stage changes, commit, and push without using the command line.
#
# If you have been using Jupyter Notebooks or Google Colab exclusively, this project is the right moment to make the transition. You can still use notebooks for exploration and prototyping, but your final scripts and Streamlit app should be developed as `.py` files in a proper editor.
#
# ### Python Environment
#
# Before installing any package for this project, create a **brand new conda environment**. This keeps your project dependencies isolated from your system Python and from other projects, avoiding version conflicts. To set it up:
#
# ```bash
# conda create -n trading-app python=3.11
# conda activate trading-app
# ```
#
# From this point on, every `pip install` you run will only affect this environment. When you are done installing your libraries, generate the `requirements.txt` file from this clean environment so it only includes the packages your project actually needs.
#
# All team members should use the same environment setup. Share the `requirements.txt` early so everyone can reproduce the same environment by running:
#
# ```bash
# pip install -r requirements.txt
# ```
#
# This also ensures that your Streamlit Cloud deployment will work correctly, since it relies on `requirements.txt` to install dependencies.
#
# ### Git and GitHub
#
# This project requires working as a team on a shared codebase. Git and GitHub are the standard tools for this, and learning to use them properly is part of the learning objectives. Here are some practical tips:
#
# 1. **Create the repository early.** One team member should create the GitHub repo and invite the rest as collaborators from day one. Don't wait until the end to put everything together.
# 2. **Use branches.** Avoid having everyone push directly to the `main` branch. A simple workflow:
#    - Each team member (or sub-team) works on their own branch (e.g., `feature/etl`, `feature/api-wrapper`, `feature/streamlit-app`).
#    - When a feature is ready, create a Pull Request to merge it into `main`.
#    - This prevents conflicts and keeps the main branch stable.
# 3. **Commit often with meaningful messages.** Small, frequent commits are better than one massive commit at the end. Write messages that describe *what* you did, for example: `"Add ETL script for AAPL data"` instead of `"update"`.
# 4. **Pull before you push.** Always run `git pull` before starting to work and before pushing your changes. This reduces merge conflicts.
# 5. **Use a `.gitignore` file.** Add a `.gitignore` to exclude files that should not be in the repository: API keys, `.env` files, `__pycache__/`, `.ipynb_checkpoints/`, large data files, etc. You can find Python-specific templates online.
# 6. **Never commit your API keys.** Store sensitive credentials in environment variables or a `.env` file that is listed in `.gitignore`. If you accidentally commit an API key, rotate it immediately.
